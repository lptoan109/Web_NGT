# %%
import tensorflow as tf
import os
import glob
import time

print(f"Đang sử dụng TensorFlow phiên bản: {tf.__version__}")
# Out:
# Đang sử dụng TensorFlow phiên bản: 2.13.0

# %%
import tensorflow as tf
import os
import glob
import time
import zipfile
import json
import io

# =============================================================================
# Ô CODE TỔNG HỢP (V7 - SỬ DỤNG CONCRETE FUNCTION)
# =============================================================================

# --- PHẦN 1: ĐỊNH NGHĨA CLASS (Giữ nguyên) ---
class FinalModelCNN(tf.keras.Model):
    def __init__(self, input_shape_config, num_classes_config, **kwargs):
        super(FinalModelCNN, self).__init__(**kwargs)
        self.input_shape_config = input_shape_config
        self.num_classes_config = num_classes_config
        self.base_model = tf.keras.applications.EfficientNetV2B2(
            weights="imagenet", 
            include_top=False, 
            input_shape=self.input_shape_config
        )
        self.gap = tf.keras.layers.GlobalAveragePooling2D(name="global_avg_pool")
        self.dense1 = tf.keras.layers.Dense(512, use_bias=False, kernel_regularizer=tf.keras.regularizers.l2(1e-5), name="dense_layer_1")
        self.bn1 = tf.keras.layers.BatchNormalization(name="batch_norm_1")
        self.act1 = tf.keras.layers.Activation('relu', name="activation_1")
        self.dropout1 = tf.keras.layers.Dropout(0.3, name="dropout_layer_1")
        self.dense2 = tf.keras.layers.Dense(256, use_bias=False, kernel_regularizer=tf.keras.regularizers.l2(1e-5), name="dense_layer_2")
        self.bn2 = tf.keras.layers.BatchNormalization(name="batch_norm_2")
        self.act2 = tf.keras.layers.Activation('relu', name="activation_2")
        self.dropout2 = tf.keras.layers.Dropout(0.2, name="dropout_layer_2")
        self.dense_output = tf.keras.layers.Dense(self.num_classes_config, activation='linear', dtype='float32', name="output_layer")

    @tf.function(input_signature=[tf.TensorSpec(shape=[None, 256, 126, 3], dtype=tf.float32)])
    def call(self, inputs, training=False):
        # Đặt training=False vì chúng ta đang ở chế độ inference
        x = self.base_model(inputs, training=training)
        x = self.gap(x, training=training) 
        x = self.dense1(x)
        x = self.bn1(x, training=training); x = self.act1(x); x = self.dropout1(x, training=training)
        x = self.dense2(x)
        x = self.bn2(x, training=training); x = self.act2(x); x = self.dropout2(x, training=training)
        outputs = self.dense_output(x)
        return outputs

print("Đã định nghĩa xong class FinalModelCNN (với weights='imagenet' và @tf.function).")
print("Bắt đầu chuyển đổi...")

# --- PHẦN 2: CẤU HÌNH VÀ CHUYỂN ĐỔI ---
BASE_DIR = os.getcwd() 
SOURCE_MODEL_DIR = os.path.join(BASE_DIR, "models") 
DEST_TFLITE_DIR = os.path.join(BASE_DIR, "models_tflite") 
MODEL_TEST_NAME = "CNN_from_NPY_no_val.keras"
INPUT_SHAPE = (256, 126, 3) 
NUM_CLASSES = 4
# ------------------

model_path = os.path.join(SOURCE_MODEL_DIR, MODEL_TEST_NAME)
tflite_name = MODEL_TEST_NAME.replace(".keras", ".tflite")
dest_path = os.path.join(DEST_TFLITE_DIR, tflite_name)

dest_path = os.path.normpath(dest_path) 
os.makedirs(os.path.normpath(DEST_TFLITE_DIR), exist_ok=True)

print(f"Model gốc: {model_path}")
print(f"Model TFLite sẽ lưu tại: {dest_path}")

if not os.path.exists(model_path):
    print(f"\n!!! LỖI KIỂM TRA: Không tìm thấy file tại đường dẫn trên. !!!")
else:
    print("\nKiểm tra: Đã tìm thấy file model. Bắt đầu chuyển đổi...")
    try:
        # === BƯỚC 1: TẠO KIẾN TRÚC ===
        print(f"\n[1/4] Đang tạo kiến trúc 'FinalModelCNN' (weights='imagenet')...")
        model = FinalModelCNN(
            input_shape_config=INPUT_SHAPE, 
            num_classes_config=NUM_CLASSES
        )
        print("[1/4] Tạo kiến trúc thành công.")

        # === BƯỚC 2: BUILD MODEL ===
        print("[2/4] Đang build model (model.build)...")
        # Build với batch_size động (None)
        model.build(input_shape=(None, INPUT_SHAPE[0], INPUT_SHAPE[1], INPUT_SHAPE[2]))
        print("[2/4] Build model thành công.")

        # === BƯỚC 3: TẢI TRỌNG SỐ ===
        print(f"[3/4] Đang tải trọng số (weights) từ: {model_path}")
        model.load_weights(model_path, by_name=True, skip_mismatch=True) 
        print("[3/4] Tải trọng số thành công (Các 'Warning' bỏ qua lớp là bình thường).")
        
        # === BƯỚC 4: CHUYỂN ĐỔI TFLITE ===
        print("[4/4] Đang khởi tạo bộ chuyển đổi TFLite...")
        
        # === SỬA LỖI: Lấy 'concrete function' ===
        # Lấy hàm 'call' đã được trace bằng @tf.function
        concrete_func = model.call.get_concrete_function()
        
        # Yêu cầu converter dùng hàm này
        converter = tf.lite.TFLiteConverter.from_concrete_functions([concrete_func])
        # ======================================
        
        converter.optimizations = [tf.lite.Optimize.DEFAULT]
        print("    -> Đang tiến hành lượng tử hóa (convert)...")
        tflite_model = converter.convert()
        print("[4/4] Chuyển đổi thành công.")
        
        print(f"    -> Đang lưu mô hình TFLite tại: {dest_path}")
        with open(dest_path, 'wb') as f:
            f.write(tflite_model)
        
        print(f"\n*** THÀNH CÔNG! Đã tạo file: {tflite_name} (Kích thước: {os.path.getsize(dest_path)} bytes) ***")
    
    except Exception as e:
        print(f"\n!!! LỖI TOÀN BỘ KHI CHUYỂN ĐỔI: {e} !!!")
        print("--- Gợi ý: Lỗi xảy ra trong quá trình tạo kiến trúc hoặc load_weights. ---")
# Out:
# Đã định nghĩa xong class FinalModelCNN (với weights='imagenet' và @tf.function).
# Bắt đầu chuyển đổi...
# Model gốc: e:\NCKH\dungcocach\Web_NGT\models\CNN_from_NPY_no_val.keras
# Model TFLite sẽ lưu tại: e:\NCKH\dungcocach\Web_NGT\models_tflite\CNN_from_NPY_no_val.tflite
#
# Kiểm tra: Đã tìm thấy file model. Bắt đầu chuyển đổi...
#
# [1/4] Đang tạo kiến trúc 'FinalModelCNN' (weights='imagenet')...
# [1/4] Tạo kiến trúc thành công.
# [2/4] Đang build model (model.build)...
# [2/4] Build model thành công.
# [3/4] Đang tải trọng số (weights) từ: e:\NCKH\dungcocach\Web_NGT\models\CNN_from_NPY_no_val.keras
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542627EE0>. Skipping object. Exception encountered: Layer 'stem_conv' expected 1 variables, but received 0 variables during loading. Expected: ['stem_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x000002153DDBE040>. Skipping object. Exception encountered: Layer 'stem_bn' expected 4 variables, but received 0 variables during loading. Expected: ['stem_bn/gamma:0', 'stem_bn/beta:0', 'stem_bn/moving_mean:0', 'stem_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542620040>. Skipping object. Exception encountered: Layer 'block1a_project_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block1a_project_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x00000215426366A0>. Skipping object. Exception encountered: Layer 'block1a_project_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block1a_project_bn/gamma:0', 'block1a_project_bn/beta:0', 'block1a_project_bn/moving_mean:0', 'block1a_project_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542620910>. Skipping object. Exception encountered: Layer 'block1b_project_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block1b_project_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x00000215426521F0>. Skipping object. Exception encountered: Layer 'block1b_project_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block1b_project_bn/gamma:0', 'block1b_project_bn/beta:0', 'block1b_project_bn/moving_mean:0', 'block1b_project_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x000002153DE34160>. Skipping object. Exception encountered: Layer 'block2a_expand_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block2a_expand_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x0000021542675B50>. Skipping object. Exception encountered: Layer 'block2a_expand_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block2a_expand_bn/gamma:0', 'block2a_expand_bn/beta:0', 'block2a_expand_bn/moving_mean:0', 'block2a_expand_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x000002154265AC70>. Skipping object. Exception encountered: Layer 'block2a_project_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block2a_project_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x000002154267A910>. Skipping object. Exception encountered: Layer 'block2a_project_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block2a_project_bn/gamma:0', 'block2a_project_bn/beta:0', 'block2a_project_bn/moving_mean:0', 'block2a_project_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x000002154265AE80>. Skipping object. Exception encountered: Layer 'block2b_expand_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block2b_expand_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x0000021542695B20>. Skipping object. Exception encountered: Layer 'block2b_expand_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block2b_expand_bn/gamma:0', 'block2b_expand_bn/beta:0', 'block2b_expand_bn/moving_mean:0', 'block2b_expand_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x000002154267A9A0>. Skipping object. Exception encountered: Layer 'block2b_project_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block2b_project_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x0000021542695A90>. Skipping object. Exception encountered: Layer 'block2b_project_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block2b_project_bn/gamma:0', 'block2b_project_bn/beta:0', 'block2b_project_bn/moving_mean:0', 'block2b_project_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542695F10>. Skipping object. Exception encountered: Layer 'block2c_expand_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block2c_expand_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x000002154286CBB0>. Skipping object. Exception encountered: Layer 'block2c_expand_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block2c_expand_bn/gamma:0', 'block2c_expand_bn/beta:0', 'block2c_expand_bn/moving_mean:0', 'block2c_expand_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x00000215426A4370>. Skipping object. Exception encountered: Layer 'block2c_project_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block2c_project_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x0000021542882610>. Skipping object. Exception encountered: Layer 'block2c_project_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block2c_project_bn/gamma:0', 'block2c_project_bn/beta:0', 'block2c_project_bn/moving_mean:0', 'block2c_project_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x00000215426CF730>. Skipping object. Exception encountered: Layer 'block3a_expand_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block3a_expand_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x00000215426ABE80>. Skipping object. Exception encountered: Layer 'block3a_expand_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block3a_expand_bn/gamma:0', 'block3a_expand_bn/beta:0', 'block3a_expand_bn/moving_mean:0', 'block3a_expand_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x00000215426AB6D0>. Skipping object. Exception encountered: Layer 'block3a_project_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block3a_project_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x000002154264BEE0>. Skipping object. Exception encountered: Layer 'block3a_project_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block3a_project_bn/gamma:0', 'block3a_project_bn/beta:0', 'block3a_project_bn/moving_mean:0', 'block3a_project_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x00000215428823A0>. Skipping object. Exception encountered: Layer 'block3b_expand_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block3b_expand_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x000002154267AE20>. Skipping object. Exception encountered: Layer 'block3b_expand_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block3b_expand_bn/gamma:0', 'block3b_expand_bn/beta:0', 'block3b_expand_bn/moving_mean:0', 'block3b_expand_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542695880>. Skipping object. Exception encountered: Layer 'block3b_project_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block3b_project_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x00000215428538B0>. Skipping object. Exception encountered: Layer 'block3b_project_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block3b_project_bn/gamma:0', 'block3b_project_bn/beta:0', 'block3b_project_bn/moving_mean:0', 'block3b_project_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542886CD0>. Skipping object. Exception encountered: Layer 'block3c_expand_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block3c_expand_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x0000021542891FD0>. Skipping object. Exception encountered: Layer 'block3c_expand_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block3c_expand_bn/gamma:0', 'block3c_expand_bn/beta:0', 'block3c_expand_bn/moving_mean:0', 'block3c_expand_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x00000215428A2970>. Skipping object. Exception encountered: Layer 'block3c_project_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block3c_project_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x000002154289DC70>. Skipping object. Exception encountered: Layer 'block3c_project_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block3c_project_bn/gamma:0', 'block3c_project_bn/beta:0', 'block3c_project_bn/moving_mean:0', 'block3c_project_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542891D60>. Skipping object. Exception encountered: Layer 'block4a_expand_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block4a_expand_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x00000215428A2880>. Skipping object. Exception encountered: Layer 'block4a_expand_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block4a_expand_bn/gamma:0', 'block4a_expand_bn/beta:0', 'block4a_expand_bn/moving_mean:0', 'block4a_expand_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x00000215428AC5B0>. Skipping object. Exception encountered: Layer 'block4a_dwconv2' expected 1 variables, but received 0 variables during loading. Expected: ['block4a_dwconv2/depthwise_kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x00000215428B3B20>. Skipping object. Exception encountered: Layer 'block4a_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block4a_bn/gamma:0', 'block4a_bn/beta:0', 'block4a_bn/moving_mean:0', 'block4a_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x00000215428D0880>. Skipping object. Exception encountered: Layer 'block4a_se_reduce' expected 2 variables, but received 0 variables during loading. Expected: ['block4a_se_reduce/kernel:0', 'block4a_se_reduce/bias:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x00000215428D0BB0>. Skipping object. Exception encountered: Layer 'block4a_se_expand' expected 2 variables, but received 0 variables during loading. Expected: ['block4a_se_expand/kernel:0', 'block4a_se_expand/bias:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x00000215428B3EE0>. Skipping object. Exception encountered: Layer 'block4a_project_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block4a_project_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x00000215428E11C0>. Skipping object. Exception encountered: Layer 'block4a_project_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block4a_project_bn/gamma:0', 'block4a_project_bn/beta:0', 'block4a_project_bn/moving_mean:0', 'block4a_project_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x00000215428C02B0>. Skipping object. Exception encountered: Layer 'block4b_expand_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block4b_expand_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x00000215428E13D0>. Skipping object. Exception encountered: Layer 'block4b_expand_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block4b_expand_bn/gamma:0', 'block4b_expand_bn/beta:0', 'block4b_expand_bn/moving_mean:0', 'block4b_expand_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x00000215428F06A0>. Skipping object. Exception encountered: Layer 'block4b_dwconv2' expected 1 variables, but received 0 variables during loading. Expected: ['block4b_dwconv2/depthwise_kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x0000021542901CA0>. Skipping object. Exception encountered: Layer 'block4b_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block4b_bn/gamma:0', 'block4b_bn/beta:0', 'block4b_bn/moving_mean:0', 'block4b_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x00000215428C28B0>. Skipping object. Exception encountered: Layer 'block4b_se_reduce' expected 2 variables, but received 0 variables during loading. Expected: ['block4b_se_reduce/kernel:0', 'block4b_se_reduce/bias:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542908A00>. Skipping object. Exception encountered: Layer 'block4b_se_expand' expected 2 variables, but received 0 variables during loading. Expected: ['block4b_se_expand/kernel:0', 'block4b_se_expand/bias:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x00000215428B3C10>. Skipping object. Exception encountered: Layer 'block4b_project_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block4b_project_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x0000021542853A00>. Skipping object. Exception encountered: Layer 'block4b_project_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block4b_project_bn/gamma:0', 'block4b_project_bn/beta:0', 'block4b_project_bn/moving_mean:0', 'block4b_project_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x00000215428AC7F0>. Skipping object. Exception encountered: Layer 'block4c_expand_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block4c_expand_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x0000021542652160>. Skipping object. Exception encountered: Layer 'block4c_expand_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block4c_expand_bn/gamma:0', 'block4c_expand_bn/beta:0', 'block4c_expand_bn/moving_mean:0', 'block4c_expand_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x00000215428FB5E0>. Skipping object. Exception encountered: Layer 'block4c_dwconv2' expected 1 variables, but received 0 variables during loading. Expected: ['block4c_dwconv2/depthwise_kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x0000021542923EB0>. Skipping object. Exception encountered: Layer 'block4c_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block4c_bn/gamma:0', 'block4c_bn/beta:0', 'block4c_bn/moving_mean:0', 'block4c_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x000002154293CAC0>. Skipping object. Exception encountered: Layer 'block4c_se_reduce' expected 2 variables, but received 0 variables during loading. Expected: ['block4c_se_reduce/kernel:0', 'block4c_se_reduce/bias:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542931C40>. Skipping object. Exception encountered: Layer 'block4c_se_expand' expected 2 variables, but received 0 variables during loading. Expected: ['block4c_se_expand/kernel:0', 'block4c_se_expand/bias:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x00000215428F0AF0>. Skipping object. Exception encountered: Layer 'block4c_project_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block4c_project_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x000002154293CD00>. Skipping object. Exception encountered: Layer 'block4c_project_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block4c_project_bn/gamma:0', 'block4c_project_bn/beta:0', 'block4c_project_bn/moving_mean:0', 'block4c_project_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542923190>. Skipping object. Exception encountered: Layer 'block4d_expand_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block4d_expand_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x00000215427B17C0>. Skipping object. Exception encountered: Layer 'block4d_expand_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block4d_expand_bn/gamma:0', 'block4d_expand_bn/beta:0', 'block4d_expand_bn/moving_mean:0', 'block4d_expand_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x0000021542945A90>. Skipping object. Exception encountered: Layer 'block4d_dwconv2' expected 1 variables, but received 0 variables during loading. Expected: ['block4d_dwconv2/depthwise_kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x0000021542945370>. Skipping object. Exception encountered: Layer 'block4d_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block4d_bn/gamma:0', 'block4d_bn/beta:0', 'block4d_bn/moving_mean:0', 'block4d_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x00000215427C17F0>. Skipping object. Exception encountered: Layer 'block4d_se_reduce' expected 2 variables, but received 0 variables during loading. Expected: ['block4d_se_reduce/kernel:0', 'block4d_se_reduce/bias:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x00000215427B7C40>. Skipping object. Exception encountered: Layer 'block4d_se_expand' expected 2 variables, but received 0 variables during loading. Expected: ['block4d_se_expand/kernel:0', 'block4d_se_expand/bias:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x00000215427C7220>. Skipping object. Exception encountered: Layer 'block4d_project_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block4d_project_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x00000215427A4130>. Skipping object. Exception encountered: Layer 'block4d_project_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block4d_project_bn/gamma:0', 'block4d_project_bn/beta:0', 'block4d_project_bn/moving_mean:0', 'block4d_project_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x00000215427ADD00>. Skipping object. Exception encountered: Layer 'block5a_expand_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block5a_expand_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x00000215427A4280>. Skipping object. Exception encountered: Layer 'block5a_expand_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block5a_expand_bn/gamma:0', 'block5a_expand_bn/beta:0', 'block5a_expand_bn/moving_mean:0', 'block5a_expand_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x00000215426D2610>. Skipping object. Exception encountered: Layer 'block5a_dwconv2' expected 1 variables, but received 0 variables during loading. Expected: ['block5a_dwconv2/depthwise_kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x0000021542793130>. Skipping object. Exception encountered: Layer 'block5a_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block5a_bn/gamma:0', 'block5a_bn/beta:0', 'block5a_bn/moving_mean:0', 'block5a_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x00000215427C76D0>. Skipping object. Exception encountered: Layer 'block5a_se_reduce' expected 2 variables, but received 0 variables during loading. Expected: ['block5a_se_reduce/kernel:0', 'block5a_se_reduce/bias:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542923640>. Skipping object. Exception encountered: Layer 'block5a_se_expand' expected 2 variables, but received 0 variables during loading. Expected: ['block5a_se_expand/kernel:0', 'block5a_se_expand/bias:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542915730>. Skipping object. Exception encountered: Layer 'block5a_project_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block5a_project_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x00000215426E8190>. Skipping object. Exception encountered: Layer 'block5a_project_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block5a_project_bn/gamma:0', 'block5a_project_bn/beta:0', 'block5a_project_bn/moving_mean:0', 'block5a_project_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x00000215426D26D0>. Skipping object. Exception encountered: Layer 'block5b_expand_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block5b_expand_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x00000215426E83A0>. Skipping object. Exception encountered: Layer 'block5b_expand_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block5b_expand_bn/gamma:0', 'block5b_expand_bn/beta:0', 'block5b_expand_bn/moving_mean:0', 'block5b_expand_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x00000215426EE8E0>. Skipping object. Exception encountered: Layer 'block5b_dwconv2' expected 1 variables, but received 0 variables during loading. Expected: ['block5b_dwconv2/depthwise_kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x00000215426F6C70>. Skipping object. Exception encountered: Layer 'block5b_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block5b_bn/gamma:0', 'block5b_bn/beta:0', 'block5b_bn/moving_mean:0', 'block5b_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x00000215426EFA90>. Skipping object. Exception encountered: Layer 'block5b_se_reduce' expected 2 variables, but received 0 variables during loading. Expected: ['block5b_se_reduce/kernel:0', 'block5b_se_reduce/bias:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x000002154270ABB0>. Skipping object. Exception encountered: Layer 'block5b_se_expand' expected 2 variables, but received 0 variables during loading. Expected: ['block5b_se_expand/kernel:0', 'block5b_se_expand/bias:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x00000215427C7910>. Skipping object. Exception encountered: Layer 'block5b_project_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block5b_project_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x0000021542A55C40>. Skipping object. Exception encountered: Layer 'block5b_project_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block5b_project_bn/gamma:0', 'block5b_project_bn/beta:0', 'block5b_project_bn/moving_mean:0', 'block5b_project_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542793D90>. Skipping object. Exception encountered: Layer 'block5c_expand_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block5c_expand_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x0000021542A55E50>. Skipping object. Exception encountered: Layer 'block5c_expand_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block5c_expand_bn/gamma:0', 'block5c_expand_bn/beta:0', 'block5c_expand_bn/moving_mean:0', 'block5c_expand_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x0000021542A7B610>. Skipping object. Exception encountered: Layer 'block5c_dwconv2' expected 1 variables, but received 0 variables during loading. Expected: ['block5c_dwconv2/depthwise_kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x0000021542A742B0>. Skipping object. Exception encountered: Layer 'block5c_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block5c_bn/gamma:0', 'block5c_bn/beta:0', 'block5c_bn/moving_mean:0', 'block5c_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542A84F70>. Skipping object. Exception encountered: Layer 'block5c_se_reduce' expected 2 variables, but received 0 variables during loading. Expected: ['block5c_se_reduce/kernel:0', 'block5c_se_reduce/bias:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542814430>. Skipping object. Exception encountered: Layer 'block5c_se_expand' expected 2 variables, but received 0 variables during loading. Expected: ['block5c_se_expand/kernel:0', 'block5c_se_expand/bias:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542828520>. Skipping object. Exception encountered: Layer 'block5c_project_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block5c_project_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x0000021542810F70>. Skipping object. Exception encountered: Layer 'block5c_project_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block5c_project_bn/gamma:0', 'block5c_project_bn/beta:0', 'block5c_project_bn/moving_mean:0', 'block5c_project_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542A65940>. Skipping object. Exception encountered: Layer 'block5d_expand_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block5d_expand_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x000002154283C7F0>. Skipping object. Exception encountered: Layer 'block5d_expand_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block5d_expand_bn/gamma:0', 'block5d_expand_bn/beta:0', 'block5d_expand_bn/moving_mean:0', 'block5d_expand_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x0000021542810F10>. Skipping object. Exception encountered: Layer 'block5d_dwconv2' expected 1 variables, but received 0 variables during loading. Expected: ['block5d_dwconv2/depthwise_kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x0000021542A5B160>. Skipping object. Exception encountered: Layer 'block5d_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block5d_bn/gamma:0', 'block5d_bn/beta:0', 'block5d_bn/moving_mean:0', 'block5d_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x000002154284EE50>. Skipping object. Exception encountered: Layer 'block5d_se_reduce' expected 2 variables, but received 0 variables during loading. Expected: ['block5d_se_reduce/kernel:0', 'block5d_se_reduce/bias:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542841340>. Skipping object. Exception encountered: Layer 'block5d_se_expand' expected 2 variables, but received 0 variables during loading. Expected: ['block5d_se_expand/kernel:0', 'block5d_se_expand/bias:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x000002154284FF40>. Skipping object. Exception encountered: Layer 'block5d_project_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block5d_project_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x00000215428412E0>. Skipping object. Exception encountered: Layer 'block5d_project_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block5d_project_bn/gamma:0', 'block5d_project_bn/beta:0', 'block5d_project_bn/moving_mean:0', 'block5d_project_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x000002154282EA90>. Skipping object. Exception encountered: Layer 'block5e_expand_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block5e_expand_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x000002154284FD30>. Skipping object. Exception encountered: Layer 'block5e_expand_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block5e_expand_bn/gamma:0', 'block5e_expand_bn/beta:0', 'block5e_expand_bn/moving_mean:0', 'block5e_expand_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x000002154275E040>. Skipping object. Exception encountered: Layer 'block5e_dwconv2' expected 1 variables, but received 0 variables during loading. Expected: ['block5e_dwconv2/depthwise_kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x0000021542758B80>. Skipping object. Exception encountered: Layer 'block5e_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block5e_bn/gamma:0', 'block5e_bn/beta:0', 'block5e_bn/moving_mean:0', 'block5e_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542766940>. Skipping object. Exception encountered: Layer 'block5e_se_reduce' expected 2 variables, but received 0 variables during loading. Expected: ['block5e_se_reduce/kernel:0', 'block5e_se_reduce/bias:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542766A90>. Skipping object. Exception encountered: Layer 'block5e_se_expand' expected 2 variables, but received 0 variables during loading. Expected: ['block5e_se_expand/kernel:0', 'block5e_se_expand/bias:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x000002154276DBE0>. Skipping object. Exception encountered: Layer 'block5e_project_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block5e_project_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x000002154277B610>. Skipping object. Exception encountered: Layer 'block5e_project_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block5e_project_bn/gamma:0', 'block5e_project_bn/beta:0', 'block5e_project_bn/moving_mean:0', 'block5e_project_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542750940>. Skipping object. Exception encountered: Layer 'block5f_expand_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block5f_expand_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x00000215427E2970>. Skipping object. Exception encountered: Layer 'block5f_expand_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block5f_expand_bn/gamma:0', 'block5f_expand_bn/beta:0', 'block5f_expand_bn/moving_mean:0', 'block5f_expand_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x00000215427F0160>. Skipping object. Exception encountered: Layer 'block5f_dwconv2' expected 1 variables, but received 0 variables during loading. Expected: ['block5f_dwconv2/depthwise_kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x00000215427E2F70>. Skipping object. Exception encountered: Layer 'block5f_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block5f_bn/gamma:0', 'block5f_bn/beta:0', 'block5f_bn/moving_mean:0', 'block5f_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x00000215427F5190>. Skipping object. Exception encountered: Layer 'block5f_se_reduce' expected 2 variables, but received 0 variables during loading. Expected: ['block5f_se_reduce/kernel:0', 'block5f_se_reduce/bias:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542803880>. Skipping object. Exception encountered: Layer 'block5f_se_expand' expected 2 variables, but received 0 variables during loading. Expected: ['block5f_se_expand/kernel:0', 'block5f_se_expand/bias:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x000002154280FFA0>. Skipping object. Exception encountered: Layer 'block5f_project_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block5f_project_conv/kernel:0']
#   _load_state(
# ...
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x00000215429F2EE0>. Skipping object. Exception encountered: Layer 'block6f_project_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block6f_project_bn/gamma:0', 'block6f_project_bn/beta:0', 'block6f_project_bn/moving_mean:0', 'block6f_project_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542AB1DF0>. Skipping object. Exception encountered: Layer 'block6g_expand_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block6g_expand_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x00000215429D8610>. Skipping object. Exception encountered: Layer 'block6g_expand_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block6g_expand_bn/gamma:0', 'block6g_expand_bn/beta:0', 'block6g_expand_bn/moving_mean:0', 'block6g_expand_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x0000021542AB2730>. Skipping object. Exception encountered: Layer 'block6g_dwconv2' expected 1 variables, but received 0 variables during loading. Expected: ['block6g_dwconv2/depthwise_kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x0000021542AB1D30>. Skipping object. Exception encountered: Layer 'block6g_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block6g_bn/gamma:0', 'block6g_bn/beta:0', 'block6g_bn/moving_mean:0', 'block6g_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542AC8C40>. Skipping object. Exception encountered: Layer 'block6g_se_reduce' expected 2 variables, but received 0 variables during loading. Expected: ['block6g_se_reduce/kernel:0', 'block6g_se_reduce/bias:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542AB6D60>. Skipping object. Exception encountered: Layer 'block6g_se_expand' expected 2 variables, but received 0 variables during loading. Expected: ['block6g_se_expand/kernel:0', 'block6g_se_expand/bias:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542AD2BE0>. Skipping object. Exception encountered: Layer 'block6g_project_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block6g_project_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x0000021542AC87C0>. Skipping object. Exception encountered: Layer 'block6g_project_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block6g_project_bn/gamma:0', 'block6g_project_bn/beta:0', 'block6g_project_bn/moving_mean:0', 'block6g_project_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542AB1BE0>. Skipping object. Exception encountered: Layer 'block6h_expand_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block6h_expand_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x0000021542AEF5B0>. Skipping object. Exception encountered: Layer 'block6h_expand_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block6h_expand_bn/gamma:0', 'block6h_expand_bn/beta:0', 'block6h_expand_bn/moving_mean:0', 'block6h_expand_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x0000021542AD2F70>. Skipping object. Exception encountered: Layer 'block6h_dwconv2' expected 1 variables, but received 0 variables during loading. Expected: ['block6h_dwconv2/depthwise_kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x0000021542AD2C40>. Skipping object. Exception encountered: Layer 'block6h_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block6h_bn/gamma:0', 'block6h_bn/beta:0', 'block6h_bn/moving_mean:0', 'block6h_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542B09970>. Skipping object. Exception encountered: Layer 'block6h_se_reduce' expected 2 variables, but received 0 variables during loading. Expected: ['block6h_se_reduce/kernel:0', 'block6h_se_reduce/bias:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542AFED00>. Skipping object. Exception encountered: Layer 'block6h_se_expand' expected 2 variables, but received 0 variables during loading. Expected: ['block6h_se_expand/kernel:0', 'block6h_se_expand/bias:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542B0E970>. Skipping object. Exception encountered: Layer 'block6h_project_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block6h_project_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x0000021542B1D1F0>. Skipping object. Exception encountered: Layer 'block6h_project_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block6h_project_bn/gamma:0', 'block6h_project_bn/beta:0', 'block6h_project_bn/moving_mean:0', 'block6h_project_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542AE8E80>. Skipping object. Exception encountered: Layer 'block6i_expand_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block6i_expand_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x0000021542B1D400>. Skipping object. Exception encountered: Layer 'block6i_expand_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block6i_expand_bn/gamma:0', 'block6i_expand_bn/beta:0', 'block6i_expand_bn/moving_mean:0', 'block6i_expand_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x0000021542B446D0>. Skipping object. Exception encountered: Layer 'block6i_dwconv2' expected 1 variables, but received 0 variables during loading. Expected: ['block6i_dwconv2/depthwise_kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x0000021542B39910>. Skipping object. Exception encountered: Layer 'block6i_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block6i_bn/gamma:0', 'block6i_bn/beta:0', 'block6i_bn/moving_mean:0', 'block6i_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542AFEC10>. Skipping object. Exception encountered: Layer 'block6i_se_reduce' expected 2 variables, but received 0 variables during loading. Expected: ['block6i_se_reduce/kernel:0', 'block6i_se_reduce/bias:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542AE8820>. Skipping object. Exception encountered: Layer 'block6i_se_expand' expected 2 variables, but received 0 variables during loading. Expected: ['block6i_se_expand/kernel:0', 'block6i_se_expand/bias:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542AB2DF0>. Skipping object. Exception encountered: Layer 'block6i_project_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block6i_project_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x0000021542AC0850>. Skipping object. Exception encountered: Layer 'block6i_project_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block6i_project_bn/gamma:0', 'block6i_project_bn/beta:0', 'block6i_project_bn/moving_mean:0', 'block6i_project_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542B1DAC0>. Skipping object. Exception encountered: Layer 'block6j_expand_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block6j_expand_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x0000021542B48550>. Skipping object. Exception encountered: Layer 'block6j_expand_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block6j_expand_bn/gamma:0', 'block6j_expand_bn/beta:0', 'block6j_expand_bn/moving_mean:0', 'block6j_expand_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x0000021542AC0EB0>. Skipping object. Exception encountered: Layer 'block6j_dwconv2' expected 1 variables, but received 0 variables during loading. Expected: ['block6j_dwconv2/depthwise_kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x0000021542B51D00>. Skipping object. Exception encountered: Layer 'block6j_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block6j_bn/gamma:0', 'block6j_bn/beta:0', 'block6j_bn/moving_mean:0', 'block6j_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542B5C910>. Skipping object. Exception encountered: Layer 'block6j_se_reduce' expected 2 variables, but received 0 variables during loading. Expected: ['block6j_se_reduce/kernel:0', 'block6j_se_reduce/bias:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542B5CA60>. Skipping object. Exception encountered: Layer 'block6j_se_expand' expected 2 variables, but received 0 variables during loading. Expected: ['block6j_se_expand/kernel:0', 'block6j_se_expand/bias:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x0000021542B6FB50>. Skipping object. Exception encountered: Layer 'block6j_project_conv' expected 1 variables, but received 0 variables during loading. Expected: ['block6j_project_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x0000021542B6F130>. Skipping object. Exception encountered: Layer 'block6j_project_bn' expected 4 variables, but received 0 variables during loading. Expected: ['block6j_project_bn/gamma:0', 'block6j_project_bn/beta:0', 'block6j_project_bn/moving_mean:0', 'block6j_project_bn/moving_variance:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.convolutional.conv2d.Conv2D object at 0x000002154262E460>. Skipping object. Exception encountered: Layer 'top_conv' expected 1 variables, but received 0 variables during loading. Expected: ['top_conv/kernel:0']
#   _load_state(
# c:\Python38\lib\site-packages\keras\src\saving\saving_lib.py:513: UserWarning: Could not load weights in object <keras.src.layers.normalization.batch_normalization.BatchNormalization object at 0x0000021542B6F280>. Skipping object. Exception encountered: Layer 'top_bn' expected 4 variables, but received 0 variables during loading. Expected: ['top_bn/gamma:0', 'top_bn/beta:0', 'top_bn/moving_mean:0', 'top_bn/moving_variance:0']
#   _load_state(
# WARNING:absl:Please consider providing the trackable_obj argument in the from_concrete_functions. Providing without the trackable_obj argument is deprecated and it will use the deprecated conversion path.
# [3/4] Tải trọng số thành công (Các 'Warning' bỏ qua lớp là bình thường).
# [4/4] Đang khởi tạo bộ chuyển đổi TFLite...
#     -> Đang tiến hành lượng tử hóa (convert)...
# [4/4] Chuyển đổi thành công.
#     -> Đang lưu mô hình TFLite tại: e:\NCKH\dungcocach\Web_NGT\models_tflite\CNN_from_NPY_no_val.tflite
#
# *** THÀNH CÔNG! Đã tạo file: CNN_from_NPY_no_val.tflite (Kích thước: 10522008 bytes) ***
